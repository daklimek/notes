# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# This code will create a pandas data frame from a CSV file.
# date_parser = pd.to_datetime is needed to get the date columns read in as datetimes.
#
# I wrote this by following this talk by Brandon Rhodes. https://www.youtube.com/watch?v=5JnMutdy6Fw
# https://github.com/brandon-rhodes/pycon-pandas-tutorial/

# %%
data = pd.read_csv('Sampled.csv', index_col=None, date_parser = pd.to_datetime)

# %%
# Sample 1000 rows.
sampled = data.sample(1000)

# %%
sampled.to_csv('Sampled.csv')

# %%
#View the first 5 rows
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0         897           847             429               145
# 1         898           949             826               151
# 2         461           351             277               275
# 3         172           600             497               247
# 4          56           339             550               855
#
#    Unnamed: 0.1.1.1.1  SalesID  SalePrice  MachineID  ModelID  datasource  \
# 0               31482  1263779      11000    1481263     3312         132
# 1              133869  1491037      32000    1435946     4107         132
# 2              188886  1625030      59000    1459598     4763         132
# 3              262094  1797518       6500    1469286     9550         132
# 4               60080  1320027      26000    1487631     3547         132
#
#          ...         Undercarriage_Pad_Width  Stick_Length  Thumb  \
# 0        ...                             NaN           NaN    NaN
# ...

# %%
# View the first 2 rows
data.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0         897           847             429               145
# 1         898           949             826               151
#
#    Unnamed: 0.1.1.1.1  SalesID  SalePrice  MachineID  ModelID  datasource  \
# 0               31482  1263779      11000    1481263     3312         132
# 1              133869  1491037      32000    1435946     4107         132
#
#          ...         Undercarriage_Pad_Width  Stick_Length  Thumb  \
# 0        ...                             NaN           NaN    NaN
# 1        ...                             NaN           NaN    NaN
#
#   Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0             NaN          NaN                  NaN        NaN
# 1             NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls
# 0                  NaN          Standard      Conventional
# ...

# %%
#View the last row
data.tail(1)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 999         717           368             737               373
#
#      Unnamed: 0.1.1.1.1  SalesID  SalePrice  MachineID  ModelID  datasource  \
# 999               93489  1404871      21000     860808     7110         132
#
#            ...         Undercarriage_Pad_Width  Stick_Length  Thumb  \
# 999        ...                             NaN           NaN    NaN
#
#     Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 999             NaN          NaN              NaN        NaN             NaN
#
#     Differential_Type Steering_Controls
# 999               NaN               NaN
#
# [1 rows x 58 columns]

# %%
#Get the number of rows in a data frame
len(data)
# Out:
# 1000

# %%
# Get one column
data['SalesID'].head(10)
# Out:
# 0    1263779
# 1    1491037
# 2    1625030
# 3    1797518
# 4    1320027
# 5    1589326
# 6    1508258
# 7    1761627
# 8    1708157
# 9    1749237
# Name: SalesID, dtype: int64

# %%
# Get one column by attribute
data.SalesID
# Out:
# 0      1263779
# 1      1491037
# 2      1625030
# 3      1797518
# 4      1320027
# 5      1589326
# 6      1508258
# 7      1761627
# 8      1708157
# 9      1749237
# 10     1378929
# 11     1374731
# 12     1801820
# 13     1205289
# 14     1747615
# 15     2232653
# 16     1608647
# 17     1617449
# 18     1281254
# 19     1721372
# 20     2352517
# 21     1346467
# 22     2298451
# 23     2260422
# 24     1509844
# 25     2358536
# 26     1272467
# 27     1168486
# 28     1608672
# 29     2257586
#         ...
# 970    1212217
# 971    2225148
# 972    4293270
# 973    1161617
# 974    1434317
# 975    1681957
# 976    2571795
# 977    2551282
# 978    1476404
# 979    1327488
# 980    1174544
# 981    1293288
# 982    1718807
# 983    1590765
# 984    1662896
# 985    6257672
# 986    1441459
# 987    1654722
# 988    1468594
# 989    1272399
# 990    1283324
# 991    1581750
# 992    2349180
# 993    1254086
# 994    1452380
# 995    1259101
# 996    1819284
# 997    1876550
# ...

# %%
# Apply subtraction on a column
data.SalePrice.head() - 99
# Out:
# 0    10901
# 1    31901
# 2    58901
# 3     6401
# 4    25901
# Name: SalePrice, dtype: int64

# %%
# Add two columns
r = data.SalePrice + data.SalePrice
r.head()
# Out:
# 0     22000
# 1     64000
# 2    118000
# 3     13000
# 4     52000
# Name: SalePrice, dtype: int64

# %%
# Create a new sorted data frame
sorted_by_sale_data = data.sort_values('saledate')

# %%
sorted_by_sale_data.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 496         602           654             591               952
# 807         523           319             238               355
# 144         425           228             649                62
# 925         326           742             862               416
# 725         185           254             479               549
#
#      Unnamed: 0.1.1.1.1  SalesID  SalePrice  MachineID  ModelID  datasource  \
# 496               57182  1313658      31000    1181225     4331         132
# 807               41453  1281889      15000    1347943     3170         132
# 144               20231  1209504       5100    1010861     9580         121
# 925              247270  1759005      14500    1120410      142         132
# 725               34744  1270551      13000    1081583     3112         132
#
#            ...         Undercarriage_Pad_Width  Stick_Length  Thumb  \
# ...

# %%
funkyYearMade = data[data['YearMade'] == 1000]

# %%
len(funkyYearMade)
# Out:
# 103

# %%
data.shape
# Out:
# (1000, 58)

# %%
# View the names of the columns and their types.
data.dtypes
# Out:
# Unnamed: 0                    int64
# Unnamed: 0.1                  int64
# Unnamed: 0.1.1                int64
# Unnamed: 0.1.1.1              int64
# Unnamed: 0.1.1.1.1            int64
# SalesID                       int64
# SalePrice                     int64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                float64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# saledate                     object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# ...

# %%
def changeColumn(df, columnName, change):
    clone = data.copy()
    clone[columnName] = change(clone[columnName])
    return clone   

changeColumn(data, 'SalePrice', lambda x : np.log(x))
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           897           847             429               145
# 1           898           949             826               151
# 2           461           351             277               275
# 3           172           600             497               247
# 4            56           339             550               855
# 5           666           594             162               755
# 6           938           141             682               645
# 7           506           619             720               709
# 8           550           119             926               306
# 9           767           990             784               702
# 10          458           780              54               733
# 11          796           384             480               357
# 12          177           812              43               530
# 13          672           621             536               676
# ...

# %%
# Generate a series of bools
r = data['Travel_Controls'] == 'None'
r.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, Unnamed: 0.1.1.1, Unnamed: 0.1.1.1.1, SalesID, SalePrice, MachineID, ModelID, datasource, auctioneerID, YearMade, MachineHoursCurrentMeter, UsageBand, saledate, fiModelDesc, fiBaseModel, fiSecondaryDesc, fiModelSeries, fiModelDescriptor, ProductSize, fiProductClassDesc, state, ProductGroup, ProductGroupDesc, Drive_System, Enclosure, Forks, Pad_Type, Ride_Control, Stick, Transmission, Turbocharged, Blade_Extension, Blade_Width, Enclosure_Type, Engine_Horsepower, Hydraulics, Pushblock, Ripper, Scarifier, Tip_Control, Tire_Size, Coupler, Coupler_System, Grouser_Tracks, Hydraulics_Flow, Track_Type, Undercarriage_Pad_Width, Stick_Length, Thumb, Pattern_Changer, Grouser_Type, Backhoe_Mounting, Blade_Type, Travel_Controls, Differential_Type, Steering_Controls]
# Index: []
#
# [0 rows x 58 columns]

# %%
# Filter based on a series of generated bools
r = data[data['Travel_Controls'] == 'None']
r.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, Unnamed: 0.1.1.1, Unnamed: 0.1.1.1.1, SalesID, SalePrice, MachineID, ModelID, datasource, auctioneerID, YearMade, MachineHoursCurrentMeter, UsageBand, saledate, fiModelDesc, fiBaseModel, fiSecondaryDesc, fiModelSeries, fiModelDescriptor, ProductSize, fiProductClassDesc, state, ProductGroup, ProductGroupDesc, Drive_System, Enclosure, Forks, Pad_Type, Ride_Control, Stick, Transmission, Turbocharged, Blade_Extension, Blade_Width, Enclosure_Type, Engine_Horsepower, Hydraulics, Pushblock, Ripper, Scarifier, Tip_Control, Tire_Size, Coupler, Coupler_System, Grouser_Tracks, Hydraulics_Flow, Track_Type, Undercarriage_Pad_Width, Stick_Length, Thumb, Pattern_Changer, Grouser_Type, Backhoe_Mounting, Blade_Type, Travel_Controls, Differential_Type, Steering_Controls]
# Index: []
#
# [0 rows x 58 columns]

# %%
data[data['Travel_Controls'].str.startswith('None', na=False) ]
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 1           898           949             826               151
# 2           461           351             277               275
# 5           666           594             162               755
# 6           938           141             682               645
# 9           767           990             784               702
# 14          281           658             253               362
# 21          144           229             823               468
# 29          815           989             182               545
# 32          442           616             169               486
# 33          576           676             241               888
# 38          578           506             506               981
# 51          140           777             257               159
# 52          511           921             208               963
# 82          128           359             566               991
# ...

# %%
# Count the number of terms
data['Travel_Controls'].value_counts()

# %%
# Count the number of terms
data['Travel_Controls'].value_counts().plot()

# %%
# Make a new data frame out of a few columns
data2 = data[['SalePrice', 'saledate']]
data2
# http://pandas.pydata.org/pandas-docs/stable/api.html
# Out:
#      SalePrice         saledate
# 0        11000  12/12/2000 0:00
# 1        32000    2/5/1997 0:00
# 2        59000   6/26/1996 0:00
# 3         6500   3/29/2000 0:00
# 4        26000   12/1/2005 0:00
# 5        46000   6/23/2011 0:00
# 6        30000   3/19/2003 0:00
# 7        14500   5/26/2009 0:00
# 8        18000   8/31/1999 0:00
# 9        17000   6/24/2004 0:00
# 10       64000  12/13/2005 0:00
# 11       33000   12/4/2001 0:00
# 12        7700  11/29/2001 0:00
# 13        8500   8/13/2010 0:00
# 14       18500  11/20/2002 0:00
# 15       78000   5/23/2007 0:00
# 16       36000   6/23/2004 0:00
# 17       13000    6/8/2000 0:00
# 18       16000    4/4/1998 0:00
# 19       69000   5/25/2005 0:00
# 20       10500    3/5/2008 0:00
# 21       29000  11/16/1993 0:00
# 22       46000  10/15/2008 0:00
# 23       25000   3/16/2007 0:00
# 24       32500    2/8/1996 0:00
# 25       32000   6/25/2008 0:00
# 26        9000   9/18/2004 0:00
# 27       42000   4/22/2010 0:00
# ...
